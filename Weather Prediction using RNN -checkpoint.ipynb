# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('seattle-weather.csv')

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
training_set = df.iloc[:,2:3].values
training_set
# Out:
# array([[12.8],
#        [10.6],
#        [11.7],
#        ...,
#        [ 7.2],
#        [ 5.6],
#        [ 5.6]])

# %%
len(training_set)
# Out:
# 1461

# %%
def df_to_XY(df,window_size=10):
 X_train=[]
 y_train=[]

 for i in range(10,len(training_set)):
    X_train.append(training_set[i-10:i,0])
    y_train.append(training_set[i,0])
    
 X_train, y_train = np.array(X_train), np.array(y_train)
 return X_train, y_train

# %%
WINDOW = 10
X,y = df_to_XY(df,WINDOW)
print(len(X),len(y))
X_train = X[:800]
y_train = y[:800]
X_val = X[800:1000]
y_val = y[800:1000]
X_test = X[1000:]
x_test = y[1000:]
# Out:
# 1451 1451

# %%
#Reshaping(To add new dimensions)
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_val = np.reshape(X_val,(X_val.shape[0],X_val.shape[1],1))
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
#Building the RNN
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
regressor = Sequential()

# %%
#Addinf the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units=50, return_sequences = True, input_shape=(X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

#Output layer
regressor.add(Dense(units=1))

# %%
#Compiling
regressor.compile(optimizer='adam',loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
#fitting the rnn to the training set
history=regressor.fit(X_train,y_train,validation_data=(X_val,y_val),epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 17s 171ms/step - loss: 205.1946 - val_loss: 247.0482
# Epoch 2/100
# 25/25 [==============================] - 1s 28ms/step - loss: 94.1933 - val_loss: 163.2353
# Epoch 3/100
# 25/25 [==============================] - 1s 28ms/step - loss: 71.8289 - val_loss: 133.5860
# Epoch 4/100
# 25/25 [==============================] - 1s 29ms/step - loss: 63.1433 - val_loss: 114.9617
# Epoch 5/100
# 25/25 [==============================] - 1s 28ms/step - loss: 58.2295 - val_loss: 102.2720
# Epoch 6/100
# 25/25 [==============================] - 1s 27ms/step - loss: 56.0517 - val_loss: 93.3626
# Epoch 7/100
# 25/25 [==============================] - 1s 25ms/step - loss: 55.1542 - val_loss: 87.2195
# Epoch 8/100
# 25/25 [==============================] - 1s 26ms/step - loss: 53.8401 - val_loss: 82.8665
# Epoch 9/100
# 25/25 [==============================] - 1s 27ms/step - loss: 53.8684 - val_loss: 79.8936
# Epoch 10/100
# 25/25 [==============================] - 1s 26ms/step - loss: 53.0271 - val_loss: 77.9826
# Epoch 11/100
# 25/25 [==============================] - 1s 26ms/step - loss: 53.8619 - val_loss: 76.9449
# Epoch 12/100
# 25/25 [==============================] - 1s 26ms/step - loss: 54.5485 - val_loss: 76.1448
# Epoch 13/100
# 25/25 [==============================] - 1s 27ms/step - loss: 53.5631 - val_loss: 76.3102
# Epoch 14/100
# 25/25 [==============================] - 1s 27ms/step - loss: 53.5936 - val_loss: 75.8682
# Epoch 15/100
# 25/25 [==============================] - 1s 26ms/step - loss: 53.4778 - val_loss: 75.8237
# Epoch 16/100
# 25/25 [==============================] - 1s 27ms/step - loss: 53.8156 - val_loss: 75.0850
# Epoch 81/100
# 25/25 [==============================] - 1s 30ms/step - loss: 9.2336 - val_loss: 10.0913
# Epoch 82/100
# 25/25 [==============================] - 1s 27ms/step - loss: 8.5708 - val_loss: 9.8250
# Epoch 83/100
# 25/25 [==============================] - 1s 26ms/step - loss: 9.1456 - val_loss: 9.9397
# Epoch 84/100
# 25/25 [==============================] - 1s 27ms/step - loss: 8.8889 - val_loss: 9.9328
# Epoch 85/100
# 25/25 [==============================] - 1s 27ms/step - loss: 8.4403 - val_loss: 9.8943
# Epoch 86/100
# 25/25 [==============================] - 1s 26ms/step - loss: 8.5150 - val_loss: 9.5985
# Epoch 87/100
# 25/25 [==============================] - 1s 27ms/step - loss: 9.0220 - val_loss: 9.5597
# Epoch 88/100
# 25/25 [==============================] - 1s 28ms/step - loss: 9.0279 - val_loss: 10.1766
# Epoch 89/100
# 25/25 [==============================] - 1s 28ms/step - loss: 8.6588 - val_loss: 9.7914
# Epoch 90/100
# 25/25 [==============================] - 1s 28ms/step - loss: 8.3468 - val_loss: 9.9149
# Epoch 91/100
# 25/25 [==============================] - 1s 27ms/step - loss: 9.0338 - val_loss: 9.9615
# Epoch 92/100
# 25/25 [==============================] - 1s 27ms/step - loss: 8.6568 - val_loss: 9.5104
# Epoch 93/100
# 25/25 [==============================] - 1s 28ms/step - loss: 8.5111 - val_loss: 10.2126
# Epoch 94/100
# 25/25 [==============================] - 1s 27ms/step - loss: 8.4990 - val_loss: 10.8499
# Epoch 95/100
# 25/25 [==============================] - 1s 28ms/step - loss: 8.1151 - val_loss: 9.8050
# Epoch 96/100
# 25/25 [==============================] - 1s 33ms/step - loss: 9.0575 - val_loss: 9.4927
# Epoch 97/100
# 25/25 [==============================] - 1s 34ms/step - loss: 8.1548 - val_loss: 9.3987
# Epoch 98/100
# 25/25 [==============================] - 1s 35ms/step - loss: 8.6728 - val_loss: 10.2517
# Epoch 99/100
# 25/25 [==============================] - 1s 35ms/step - loss: 8.8022 - val_loss: 9.6084
# Epoch 100/100
# 25/25 [==============================] - 1s 35ms/step - loss: 8.3060 - val_loss: 9.6584

# %%
his = pd.DataFrame(history.history)

# %%
his.head()
# Out:
#          loss    val_loss
# 0  205.194626  247.048218
# 1   94.193268  163.235306
# 2   71.828873  133.585953
# 3   63.143253  114.961700
# 4   58.229542  102.271996

# %%
import seaborn as sns
his.columns
history_loss = his[['loss', 'val_loss']]


fig,axes = plt.subplots(2,1,figsize=(14,8))
plt.subplot(2,1,1)
plt.title("Loss & Val Loss")
sns.lineplot(data=history_loss,palette="flare");

# %%
train_pred = regressor.predict(X_train).flatten()
val_pred = regressor.predict(X_val).flatten()
test_pred = regressor.predict(X_test).flatten()
# Out:
# 25/25 [==============================] - 3s 9ms/step
# 7/7 [==============================] - 3s 8ms/step
# 15/15 [==============================] - 0s 9ms/step

# %%
pred = np.concatenate([train_pred,val_pred,test_pred])
df_pred = pd.DataFrame(df["temp_max"].copy())
df_pred.columns=["actual"]
df_pred = df_pred[WINDOW:]
df_pred["predicted"] = pred

fig,axes = plt.subplots(2,1,figsize=(14,8),dpi=400)

plt.subplot(2,1,1)
plt.title("Validation Results")
sns.lineplot(data=df_pred[800:],alpha=0.8,palette="flare",linestyle=None);

plt.subplot(2,1,2)
plt.title("Test Results")
sns.lineplot(data=df_pred[1000:],alpha=0.8,palette="flare",linestyle=None);
